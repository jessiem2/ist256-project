# %%
# !pip install git+https://github.com/python-visualization/folium.git
# Out:
# Collecting git+https://github.com/python-visualization/folium.git
#   Cloning https://github.com/python-visualization/folium.git to /tmp/pip-req-build-__2ph988
#   Running command git clone -q https://github.com/python-visualization/folium.git /tmp/pip-req-build-__2ph988
# Requirement already satisfied (use --upgrade to upgrade): folium==0.10.1+22.gc86edb1 from git+https://github.com/python-visualization/folium.git in /opt/conda/lib/python3.7/site-packages
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/lib/python3.7/site-packages (from folium==0.10.1+22.gc86edb1) (0.3.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.7/site-packages (from folium==0.10.1+22.gc86edb1) (2.10.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from folium==0.10.1+22.gc86edb1) (1.17.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from folium==0.10.1+22.gc86edb1) (2.12.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from branca>=0.3.0->folium==0.10.1+22.gc86edb1) (1.13.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2>=2.9->folium==0.10.1+22.gc86edb1) (1.1.1)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.10.1+22.gc86edb1-py2.py3-none-any.whl size=93692 sha256=a8559d18b5da79886bbdba35c0cbb803377610799aa78c302aaee10b24bfe53f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fvisl8w4/wheels/e7/9d/fb/0526aecb47b5ed7e199de000ffa4ba9af6b30ad365c4802813
# Successfully built folium

# %%
import requests

apikey = '58846e1b2ea8652926535729c9d3b4f4'
country = 'united states'
url = f'https://ws.audioscrobbler.com/2.0/?method=geo.gettoptracks&country={country}&api_key={apikey}&format=json&limit=5'

response = requests.get(url)
content = response.json()
content
# Out:
# {'tracks': {'track': [{'name': "Can't Feel My Face",
#     'duration': '0',
#     'listeners': '529675',
#     'mbid': '',
#     'url': 'https://www.last.fm/music/The+Weeknd/_/Can%27t+Feel+My+Face',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'artist': {'name': 'The Weeknd',
#      'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#      'url': 'https://www.last.fm/music/The+Weeknd'},
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'}],
#     '@attr': {'rank': '0'}},
#    {'name': 'Hotline Bling',
#     'duration': '0',
#     'listeners': '421084',
#     'mbid': '',
#     'url': 'https://www.last.fm/music/Drake/_/Hotline+Bling',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'artist': {'name': 'Drake',
#      'mbid': 'b49b81cc-d5b7-4bdd-aadb-385df8de69a6',
#      'url': 'https://www.last.fm/music/Drake'},
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'}],
#     '@attr': {'rank': '1'}},
#    {'name': 'The Less I Know the Better',
#     'duration': '0',
#     'listeners': '561763',
#     'mbid': '',
#     'url': 'https://www.last.fm/music/Tame+Impala/_/The+Less+I+Know+the+Better',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'artist': {'name': 'Tame Impala',
#      'mbid': '63aa26c3-d59b-4da4-84ac-716b54f1ef4d',
#      'url': 'https://www.last.fm/music/Tame+Impala'},
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'}],
#     '@attr': {'rank': '2'}},
#    {'name': 'Mr. Brightside',
#     'duration': '224',
#     'listeners': '2072548',
#     'mbid': '37d516ab-d61f-4bcb-9316-7a0b3eb845a8',
#     'url': 'https://www.last.fm/music/The+Killers/_/Mr.+Brightside',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'artist': {'name': 'The Killers',
#      'mbid': '95e1ead9-4d31-4808-a7ac-32c3614c116b',
#      'url': 'https://www.last.fm/music/The+Killers'},
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'}],
#     '@attr': {'rank': '3'}},
#    {'name': 'Hello',
#     'duration': '0',
#     'listeners': '453627',
#     'mbid': '',
#     'url': 'https://www.last.fm/music/Adele/_/Hello',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'artist': {'name': 'Adele',
#      'mbid': 'cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493',
#      'url': 'https://www.last.fm/music/Adele'},
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'}],
#     '@attr': {'rank': '4'}}],
#   '@attr': {'country': 'United States',
#    'page': '1',
#    'perPage': '5',
#    'totalPages': '2849484',
#    'total': '14247418'}}}

# %%
import pandas as pd
import numpy as np
import folium
import json
import warnings
warnings.filterwarnings('ignore')

apikey = "58846e1b2ea8652926535729c9d3b4f4"
mydict = {'country' : []}
for i in range(5):
    mydict['track' + str(i+1)] = []
    mydict['artist' + str(i+1)] = []
countries = ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
            'Austria',
            'Azerbaijan',
            'Bahamas',
            'Bahrain',
            'Bangladesh',
            'Barbados',
            'Belarus',
            'Belgium',
            'Belize',
            'Benin',
            'Bermuda',
            'Bhutan',
            'Bolivia',
            'Bosnia and Herzegovina',
            'Botswana',
            'Brazil',
            'Brunei Darussalam',
            'Bulgaria',
            'Burkina Faso',
            'Burundi',
            'Cambodia',
            'Cameroon',
            'Canada',
            'Cayman Islands',
            'Chad',
            'Chile',
            'China',
            'Colombia',
            'Congo',
            'Costa Rica',
            'Croatia',
            'Cuba',
            'Cyprus',
            'Czech Republic',
            'Denmark',
            'Djibouti',
            'Dominica',
            'Dominican Republic',
            'Ecuador',
            'Egypt',
            'El Salvador',
            'Equatorial Guinea',
            'Estonia',
            'Ethiopia',
            'Faroe Islands',
            'Fiji',
            'Finland',
            'France',
            'French Guiana',
            'French Polynesia',
            'Gabon',
            'Gambia',
            'Georgia',
            'Germany',
            'Ghana',
            'Gibraltar',
            'Greece',
            'Greenland',
            'Grenada',
            'Guadeloupe',
            'Guam',
            'Guatemala',
            'Guernsey',
            'Guyana',
            'Haiti',
            'Israel',
            'Italy',
            'Honduras',
            'Hong Kong',
            'Hungary',
            'Iceland',
            'India',
            'Indonesia',
            'Iraq',
            'Ireland',
            'Isle of Man',
            'Jamaica',
            'Japan',
            'Jersey',
            'Jordan',
            'Kazakhstan',
            'Kenya',
            'Kuwait',
            'Kyrgyzstan',
            'Latvia',
            'Lebanon',
            'Liechtenstein',
            'Lithuania',
            'Luxembourg',
            'Macao',
            'Macedonia',
            'Madagascar',
            'Malawi',
            'Malaysia',
            'Maldives',
            'Mali',
            'Malta',
            'Namibia',
            'Nepal',
            'Netherlands',
            'New Caledonia',
            'New Zealand',
            'Nicaragua',
            'Nigeria',
            'Norfolk Island',
            'Northern Mariana Islands',
            'Norway',
            'Oman',
            'Pakistan',
            'Palau',
            'Panama',
            'Paraguay',
            'Peru',
            'Philippines',
            'Poland',
            'Portugal',
            'Puerto Rico',
            'Qatar',
            'Romania',
            'Russian Federation',
            'Rwanda',
            'Saint Kitts and Nevis',
            'Saint Lucia',
            'Singapore',
            'Samoa',
            'San Marino',
            'Saudi Arabia',
            'Senegal',
            'Serbia',
            'Seychelles',
            'Slovakia',
            'Slovenia',
            'Solomon Islands',
            'South Africa',
            'Spain',
            'Sri Lanka',
            'Sudan',
            'Suriname',
            'Swaziland',
            'Sweden',
            'Switzerland',
            'Syrian Arab Republic',
            'Taiwan',
            'Tajikistan',
            'Thailand',
            'Timor-Leste',
            'Togo',
            'Tonga',
            'Uganda',
            'Ukraine',
            'United Arab Emirates',
            'United Kingdom',
            'United States',
            'Uruguay',
            'Uzbekistan',
            'Vanuatu',
            'Venezuela',
            'Viet Nam',
            'Yemen',
            'Zambia',
            'Zimbabwe']

for country in countries:
    url = f'https://ws.audioscrobbler.com/2.0/?method=geo.gettoptracks&country={country}&api_key={apikey}&format=json&limit=5'
    response = requests.get(url)
    content = response.json()
    
    mydict['country'].append(country)
    for i in range(5):
        mydict['track' + str(i+1)].append(content['tracks']['track'][i]['name'])
        mydict['artist' + str(i+1)].append(content['tracks']['track'][i]['artist']['name'])
               
mydataframe = pd.DataFrame.from_dict(mydict)

display(mydataframe)
# Out:
#             country                      track1         artist1  \
# 0       Afghanistan                  Wonderwall           Oasis
# 1           Albania  The Less I Know the Better     Tame Impala
# 2           Algeria            Do I Wanna Know?  Arctic Monkeys
# 3    American Samoa     Smells Like Teen Spirit         Nirvana
# 4           Andorra                       Creep       Radiohead
# ..              ...                         ...             ...
# 163       Venezuela          Can't Feel My Face      The Weeknd
# 164        Viet Nam                       Hello           Adele
# 165           Yemen                       Hello           Adele
# 166          Zambia            Do I Wanna Know?  Arctic Monkeys
# 167        Zimbabwe               The Scientist        Coldplay
#
#                       track2        artist2                 track3  \
# 0              Midnight City            M83           Breezeblocks
# 1              Let It Happen    Tame Impala          The Scientist
# 2         Losing My Religion         R.E.M.             Wonderwall
# 3                      Creep      Radiohead                  Intro
# 4    Love Will Tear Us Apart   Joy Division          The Passenger
# ..                       ...            ...                    ...
# 163                    Creep      Radiohead                  Sorry
# 164         Someone Like You          Adele          The Scientist
# 165            Cheap Thrills            Sia  Make You Feel My Love
# 166              Video Games   Lana Del Rey     Can't Feel My Face
# 167                   Ho Hey  The Lumineers                   Team
#
#            artist3                 track4         artist4  \
# 0            alt-J       Heart-Shaped Box         Nirvana
# 1         Coldplay      Where Is My Mind?          Pixies
# 2            Oasis           Shape of You      Ed Sheeran
# 3           The xx           Karma Police       Radiohead
# 4         Iggy Pop       Do I Wanna Know?  Arctic Monkeys
# ..             ...                    ...             ...
# 163  Justin Bieber                  Hello           Adele
# 164       Coldplay  Make You Feel My Love           Adele
# 165          Adele          Hotline Bling           Drake
# 166     The Weeknd                  Hello           Adele
# 167          Lorde                 Africa            Toto
#
#                       track5            artist5
# 0       The Sound of Silence  Simon & Garfunkel
# 1               No Surprises          Radiohead
# 2                      Creep          Radiohead
# 3            Come as You Are            Nirvana
# 4    Smells Like Teen Spirit            Nirvana
# ..                       ...                ...
# 163         Do I Wanna Know?     Arctic Monkeys
# 164             Shape of You         Ed Sheeran
# 165                One Dance              Drake
# 166            Hotline Bling              Drake
# 167               Let Her Go          Passenger
#
# [168 rows x 11 columns]

# %%
import requests
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')


maxsongs = 5
apikey = '58846e1b2ea8652926535729c9d3b4f4'
mydict = {'name' : []}
geography = pd.read_csv('countries.csv')
names = geography['name'].to_list()

for i in range(maxsongs):
    mydict['track' + str(i+1)] = []
    mydict['artist' + str(i+1)] = []  

for name in names:
    url = f'https://ws.audioscrobbler.com/2.0/?method=geo.gettoptracks&country={name}&api_key={apikey}&format=json&limit={str(maxsongs)}'
    response = requests.get(url)
    content = response.json()
    num = int(content['tracks']['@attr']['total'])
    
        
    mydict['name'].append(name)
    for i in range(maxsongs):
        if i < num:
            mydict['track' + str(i+1)].append(content['tracks']['track'][i]['name'])
            mydict['artist' + str(i+1)].append(content['tracks']['track'][i]['artist']['name'])
        else:
            mydict['track' + str(i+1)].append('None')
            mydict['artist' + str(i+1)].append('None')

toptracks = pd.DataFrame.from_dict(mydict)
df = pd.merge(left=toptracks, right=geography)

# %%
import folium
print('please wait')
center = (0, 0)
country_geojson = 'https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json'
map1 = folium.Map(location=center, zoom_start=2)
folium.Choropleth(geo_data=country_geojson, fill_color='red', line_color='blue').add_to(map1)

for row in df.to_records():
    pos = (row['latitude'],row['longitude'])
    message = f"Top 5 songs in {row['name']}: <br> 1- {row['track1']} by {row['artist1']} <br> 2- {row['track2']} by {row['artist2']} <br> 3- {row['track3']} by {row['artist3']} <br> 4- { row['track4']} by {row['artist4']} <br> 5- {row['track5']} by {row['artist5']}"
    popup = folium.Popup(max_width=300,min_width=300, html=message)
    marker = folium.Marker(location=pos, popup=popup)
    
    map1.add_child(marker)

map1
# Out:
# please wait
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
